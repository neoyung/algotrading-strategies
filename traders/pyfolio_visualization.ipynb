# %%
import sys
sys.path.insert(0, "..")
import warnings
warnings.filterwarnings("ignore")

# %run ./test_trader.py
# Out:
# 2017-09-11 00:00:00, Coming 3 days BTC going up or dn: 0.
# 2017-09-12 00:00:00, Coming 3 days BTC going up or dn: 0.
# 2017-09-13 00:00:00, Coming 3 days BTC going up or dn: 0.
# 2017-09-14 00:00:00, Coming 3 days BTC going up or dn: 0.
# 2017-09-15 00:00:00, Coming 3 days BTC going up or dn: 1.
# 2017-09-15 00:00:00, Buy created @ price: 3700.00
# 2017-09-16 00:00:00, Order Submitted.
# 2017-09-16 00:00:00, Order Accepted.
# 2017-09-16 00:00:00, -> Buy executed, Price: 3674.01, Cost: 98304.59, Comm 98.30
# 2017-09-18 00:00:00, Order created to close position last executed.
# 2017-09-19 00:00:00, Order Submitted.
# 2017-09-19 00:00:00, Order Accepted.
# 2017-09-19 00:00:00, -> Sell executed, Price: 4060.00, Cost: 98304.59, Comm 108.63
# 2017-09-19 00:00:00, -> Trade profit, Gross 10327.84, Net 10120.90
# 2017-09-19 00:00:00, Coming 3 days BTC going up or dn: 1.
# 2017-09-19 00:00:00, Buy created @ price: 3910.04
# 2017-09-20 00:00:00, Order Submitted.
# ...
